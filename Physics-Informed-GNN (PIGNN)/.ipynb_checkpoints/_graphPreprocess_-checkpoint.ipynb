# %%
# This notebook preprocesses the dataset
# The full data (1033 graphs) is about 9Go

# %%
import networkx as nx
import pickle
import random
import warnings 
import glob
import os
import torch
warnings.filterwarnings('ignore')

# %%
def _doPreprocess(G):
    # 1. Generate the feature matrix
    def GenerateFeatureMatrixF(G):
        label_combinations = [['Base', 'Computer'], ['Base', 'OU'], ['Base', 'User'], ['Base', 'Group'], 
                              ['Base', 'GPO'], ['Base', 'Domain']]
        operating_systems = ["Windows Server 2003", "Windows Server 2008", "Windows 7", "Windows 10", 
                             "Windows XP", "Windows Server 2012", "Windows Server 2008"]
        properties = ["enabled", "hasspn", "highvalue", "is_vulnerable", "target", "owned"]

        label_to_index = {str(label): idx for idx, label in enumerate(label_combinations)}
        os_to_index = {os: idx for idx, os in enumerate(operating_systems)}
        
        num_nodes = len(G.nodes())
        num_features = len(label_combinations) + len(properties) + len(operating_systems)
        feature_matrix = torch.zeros((num_nodes, num_features), dtype=torch.float32)

        node_id_to_index = {node: idx for idx, node in enumerate(G.nodes())}
        
        # One-hot encoding of node properties
        for node, data in G.nodes(data=True):
            idx = node_id_to_index[node]  # Get node index

            # Encode label combinations
            for label_combination in label_combinations:
                if all(item in data['labels'] for item in label_combination):  
                    feature_matrix[idx, label_to_index[str(label_combination)]] = 1

            # Encode operating system
            os_value = data.get('properties', {}).get('operatingsystem', None)
            if os_value in os_to_index:
                feature_matrix[idx, len(label_combinations) + len(properties) + os_to_index[os_value]] = 1

            # Encode boolean properties
            for prop_idx, prop in enumerate(properties):
                if data.get("properties", {}).get(prop, False):  
                    feature_matrix[idx, len(label_combinations) + prop_idx] = 1

        return feature_matrix

    FeatureMatrix = GenerateFeatureMatrixF(G)

    # 2. Create adjacency tensor for different edge types
    edge_types = ["AdminTo", "AllowedToDelegate", "CanRDP", "Contains", "DCSync", "ExecuteDCOM", 
                  "GenericAll", "GetChanges", "GetChangesAll", "GpLink", "HasSession", "MemberOf", 
                  "Open", "Owns", "WriteDacl", "WriteOwner"]

    num_nodes = len(G.nodes())
    num_edge_types = len(edge_types)
    adj_tensor = torch.zeros((num_nodes, num_nodes, num_edge_types), dtype=torch.float32)
    
    node_id_to_index = {node: idx for idx, node in enumerate(G.nodes())}
    
    for edge_type_idx, edge_type in enumerate(edge_types):
        for u, v, data in G.edges(data=True):
            if data.get('type_') == edge_type:
                u_idx = node_id_to_index[u]  
                v_idx = node_id_to_index[v]  
                adj_tensor[u_idx, v_idx, edge_type_idx] = 1  

    # 3. Generate a target prediction adjacency matrix for each unique "pathId" value on "optimal" edges
    Y_nodes = set()
    X_matrices = []
    Y_matrices = []
    
    # Helper mapping node names to indices
    node_name_to_index = {data['properties']['name']: idx for idx, (node, data) in enumerate(G.nodes(data=True))}
    
    # Identify unique paths based on 'pathId'
    for u, v, data in G.edges(data=True):
        if data.get('type_') == "optimal":
            Y_nodes.add(data['properties']['pathId'])  # Collect unique pathIds
            
    for y_node in Y_nodes:
        y_matrix = torch.zeros((num_nodes, num_nodes), dtype=torch.int64)  # Ensure 2D shape
        for u, v, data in G.edges(data=True):
            if data.get('type_') == "optimal" and data.get('properties', {}).get('pathId') == y_node:
                u_idx = node_id_to_index[u]  
                v_idx = node_id_to_index[v]  
                y_matrix[u_idx, v_idx] = 1  
                
        Y_matrices.append(y_matrix)

    # Generate feature matrix for each "owned" start node
    for y_node in Y_nodes:
        x_matrix = FeatureMatrix.clone()  # Copy the feature matrix

        # Step 1: Reset all "owned" indicators
        x_matrix[:, -1] = 0  

        # Step 2: Find the correct start node and mark it
        y_idx = node_name_to_index.get(y_node, None)
        if y_idx is not None:
            x_matrix[y_idx, -1] = 1  # Mark "owned"

        X_matrices.append(x_matrix)

    adj_tensor = adj_tensor.float()

    # Create a mapping from node index to actual node ID
    index_to_node = {idx: node for idx, node in enumerate(G.nodes())}
    
    return adj_tensor, X_matrices, Y_matrices, list(Y_nodes), edge_types, index_to_node

def load_graph(graph_path):
    with open(graph_path, "rb") as f:
        return pickle.load(f)

def preprocess_graph(G):
    if len(G.nodes()) != 361:
        return None  # Skip processing if node count is incorrect
    
    adj_tensor, X_matrices, Y_matrices, Y_nodes, edge_types, index_to_node = _doPreprocess(G)
    
    if not X_matrices or not Y_matrices:
        return None  # Skip if no valid paths exist
    
    # Randomly select one path
    selected_idx = random.randint(0, len(X_matrices) - 1)
    return adj_tensor, X_matrices[selected_idx], Y_matrices[selected_idx]

def process_dataset(dataset_dir, output_dir):
    os.makedirs(output_dir, exist_ok=True)

    total = 0
    for filename in os.listdir(dataset_dir):
        if filename.endswith(".pickle"):
            graph_path = os.path.join(dataset_dir, filename)
            
            G = load_graph(graph_path)
            processed_data = preprocess_graph(G)
            
            if processed_data is None:
                print(f"Removing invalid graph: {filename}")
                os.remove(graph_path)
                continue
            
            adj_tensor, X_matrix, Y_matrix = processed_data
            
            output_path = os.path.join(output_dir, filename.replace(".pickle", ".pt"))
            torch.save({
                "adj_tensor": adj_tensor,
                "X_matrix": X_matrix,
                "Y_matrix": Y_matrix
            }, output_path)

            total+=1
            print(f"Processed and saved: {output_path}")
            
    print(f"[+] Done, {total} graphs have been preprocessd !")

# %%
input_folder = "<insert .pickle here>"
output_folder = "_data_"
process_dataset(input_folder, output_folder)
# Out:
# Processed and saved: _data_/graph_jV3LdG20.pt
# Processed and saved: _data_/graph_00hliAZI.pt
# Processed and saved: _data_/graph_036Idcma.pt
# Processed and saved: _data_/graph_04rUpi8y.pt
# Processed and saved: _data_/graph_0drBUl8N.pt
# Processed and saved: _data_/graph_0LfRgXU1.pt
# Processed and saved: _data_/graph_0Lw4zenj.pt
# Processed and saved: _data_/graph_0S7NNh0c.pt
# Processed and saved: _data_/graph_0V9GStgY.pt
# Processed and saved: _data_/graph_0y42FJQ8.pt
# Processed and saved: _data_/graph_17V9fxNz.pt
# Processed and saved: _data_/graph_19PxHsXJ.pt
# Processed and saved: _data_/graph_1az1V5Ue.pt
# Processed and saved: _data_/graph_1BTSm7RP.pt
# Processed and saved: _data_/graph_1fBE7jxj.pt
# Processed and saved: _data_/graph_1hJozdNw.pt
# Processed and saved: _data_/graph_1hyY6WK7.pt
# Processed and saved: _data_/graph_1Lxpeuur.pt
# Processed and saved: _data_/graph_FkOiHF09.pt
# Processed and saved: _data_/graph_FL1lfimk.pt
# Processed and saved: _data_/graph_fMrr7sps.pt
# Processed and saved: _data_/graph_fnA4BE2s.pt
# Processed and saved: _data_/graph_fNr1Vd8O.pt
# Processed and saved: _data_/graph_FNzc1ALm.pt
# Processed and saved: _data_/graph_fOXH7BoD.pt
# Processed and saved: _data_/graph_FOxuGLUk.pt
# Processed and saved: _data_/graph_FpHkXU0F.pt
# Processed and saved: _data_/graph_FPtmWqyR.pt
# Processed and saved: _data_/graph_FTGR3eyF.pt
# Processed and saved: _data_/graph_FtnlsxI5.pt
# Processed and saved: _data_/graph_FtZb7TNt.pt
# Processed and saved: _data_/graph_FtZN4C0p.pt
# Processed and saved: _data_/graph_FUp1TSPr.pt
# Processed and saved: _data_/graph_fv57CclR.pt
# Processed and saved: _data_/graph_fVCfpkOz.pt
# Processed and saved: _data_/graph_qI5K61Zg.pt
# Processed and saved: _data_/graph_Qj8pA6xJ.pt
# Processed and saved: _data_/graph_qJCnHw7W.pt
# Processed and saved: _data_/graph_qMEcesND.pt
# Processed and saved: _data_/graph_qmZ33VsN.pt
# Processed and saved: _data_/graph_QNHbOpyC.pt
# Processed and saved: _data_/graph_qQH46GUW.pt
# Processed and saved: _data_/graph_QsaHne0u.pt
# Processed and saved: _data_/graph_qsn3R3e6.pt
# Processed and saved: _data_/graph_QtjVdVNp.pt
# Processed and saved: _data_/graph_qW9FMmzk.pt
# Processed and saved: _data_/graph_qW9iuZFn.pt
# Processed and saved: _data_/graph_qwAQRSgU.pt
# Processed and saved: _data_/graph_QwY6wLlX.pt
# Processed and saved: _data_/graph_QXDaKbsg.pt
# Processed and saved: _data_/graph_QygAWjmn.pt
# Processed and saved: _data_/graph_qyHGZkvz.pt
# Processed and saved: _data_/graph_qYIPmNH2.pt
# Processed and saved: _data_/graph_Qz8N20w7.pt
# Processed and saved: _data_/graph_qZcXNiUK.pt
# Processed and saved: _data_/graph_QzrNj4Q9.pt
# Processed and saved: _data_/graph_aBo3L8pa.pt
# Processed and saved: _data_/graph_aC6gXqnX.pt
# Processed and saved: _data_/graph_ACBLCQut.pt
# Processed and saved: _data_/graph_AdNe32n1.pt
# Processed and saved: _data_/graph_aeEruMpy.pt
# Processed and saved: _data_/graph_af74k78L.pt
# Processed and saved: _data_/graph_aHr4HnHW.pt
# Processed and saved: _data_/graph_AJ03TVOO.pt
# Processed and saved: _data_/graph_AKVdH05x.pt
# Processed and saved: _data_/graph_ALDzF71U.pt
# Processed and saved: _data_/graph_AMnOOE9f.pt
# Processed and saved: _data_/graph_aNJKXn6X.pt
# Processed and saved: _data_/graph_anLaKWGQ.pt
# Processed and saved: _data_/graph_ANtufe5n.pt
# Processed and saved: _data_/graph_Ao4btwL3.pt
# Processed and saved: _data_/graph_aPr6DEWk.pt
# Processed and saved: _data_/graph_AprysH2F.pt
# Processed and saved: _data_/graph_AqlxPNvA.pt
# Processed and saved: _data_/graph_ARoChExk.pt
# Processed and saved: _data_/graph_aTfZeg4f.pt
# Processed and saved: _data_/graph_aU7puv6V.pt
# Processed and saved: _data_/graph_AUkpahxb.pt
# Processed and saved: _data_/graph_aXA1MrJL.pt
# Processed and saved: _data_/graph_AYJY0fsv.pt
# Processed and saved: _data_/graph_AZCtlvtl.pt
# Processed and saved: _data_/graph_AZSWJei5.pt
# Processed and saved: _data_/graph_azXKG9Fn.pt
# Processed and saved: _data_/graph_1MbBuV6m.pt
# Processed and saved: _data_/graph_2PYffHXR.pt
# Processed and saved: _data_/graph_3xWzTvVt.pt
# Processed and saved: _data_/graph_5o6lFFVM.pt
# Processed and saved: _data_/graph_6PNPKqn7.pt
# Processed and saved: _data_/graph_85VxnRWo.pt
# Processed and saved: _data_/graph_9A4Qbyv6.pt
# Processed and saved: _data_/graph_aBcOYDui.pt
# Processed and saved: _data_/graph_B0GC6jXW.pt
# Processed and saved: _data_/graph_BG4ydDJw.pt
# Processed and saved: _data_/graph_bVCdF2ZP.pt
# Processed and saved: _data_/graph_CIaRaWhF.pt
# Processed and saved: _data_/graph_CtcF1Rqa.pt
# Processed and saved: _data_/graph_DeoHMfk8.pt
# Processed and saved: _data_/graph_DxGiZa4o.pt
# Processed and saved: _data_/graph_EKGc2lqC.pt
# Processed and saved: _data_/graph_EWWVOjUM.pt
# Processed and saved: _data_/graph_FKaeq6rc.pt
# Processed and saved: _data_/graph_fvhO2sZv.pt
# Processed and saved: _data_/graph_ghO31Qqq.pt
# Processed and saved: _data_/graph_h5HHdvJm.pt
# Processed and saved: _data_/graph_hhmtZQlx.pt
# Processed and saved: _data_/graph_I5OuEe6k.pt
# Processed and saved: _data_/graph_iynzpTUc.pt
# Processed and saved: _data_/graph_koKPyD3m.pt
# Processed and saved: _data_/graph_kP3seozc.pt
# Processed and saved: _data_/graph_KPIzowgQ.pt
# Processed and saved: _data_/graph_KpO2PlIV.pt
# Processed and saved: _data_/graph_krk1OpyA.pt
# Processed and saved: _data_/graph_kV1BbKxm.pt
# Processed and saved: _data_/graph_KvmK9zXF.pt
# Processed and saved: _data_/graph_KvVJI8N9.pt
# Processed and saved: _data_/graph_Kw9LKiBO.pt
# Processed and saved: _data_/graph_L14IKFrP.pt
# Processed and saved: _data_/graph_L1CisSBa.pt
# Processed and saved: _data_/graph_l5WQV0zb.pt
# Processed and saved: _data_/graph_L6Yj9Aag.pt
# Processed and saved: _data_/graph_LAZ8OtX2.pt
# Processed and saved: _data_/graph_LbL8cpoN.pt
# Processed and saved: _data_/graph_LCRE2z49.pt
# Processed and saved: _data_/graph_lDMTX57X.pt
# Processed and saved: _data_/graph_lGB4k6cn.pt
# Processed and saved: _data_/graph_Li4Ml5Wn.pt
# Processed and saved: _data_/graph_lIZ7vDmW.pt
# Processed and saved: _data_/graph_LkMgYSO0.pt
# Processed and saved: _data_/graph_LLhFIrvu.pt
# Processed and saved: _data_/graph_LlP3lDKA.pt
# Processed and saved: _data_/graph_LNQC8V7D.pt
# Processed and saved: _data_/graph_tVwdWzbn.pt
# Processed and saved: _data_/graph_Tx8WBuzi.pt
# Processed and saved: _data_/graph_tZpthu79.pt
# Processed and saved: _data_/graph_TZV6u2H8.pt
# Processed and saved: _data_/graph_U1Lv78A2.pt
# Processed and saved: _data_/graph_u29VoLzu.pt
# Processed and saved: _data_/graph_u2ETjDP3.pt
# Processed and saved: _data_/graph_U9aUI67F.pt
# Processed and saved: _data_/graph_udbvz7IM.pt
# Processed and saved: _data_/graph_ueRns4h5.pt
# Processed and saved: _data_/graph_UFmpmIxv.pt
# Processed and saved: _data_/graph_ujSJRmpJ.pt
# Processed and saved: _data_/graph_ulAnGLCD.pt
# Processed and saved: _data_/graph_uN6pjvTN.pt
# Processed and saved: _data_/graph_UnmPYItE.pt
# Processed and saved: _data_/graph_UOInLBP3.pt
# Processed and saved: _data_/graph_Urf20CrW.pt
# Processed and saved: _data_/graph_uSgu8FMc.pt
# Processed and saved: _data_/graph_usRsvxJr.pt
# Processed and saved: _data_/graph_BVn5gurl.pt
# Processed and saved: _data_/graph_bwaR7ooe.pt
# Processed and saved: _data_/graph_bwcPae3N.pt
# Processed and saved: _data_/graph_bxK8EpBY.pt
# Processed and saved: _data_/graph_bxO1x9sA.pt
# Processed and saved: _data_/graph_by5nnGzH.pt
# Processed and saved: _data_/graph_BZtC4PsF.pt
# Processed and saved: _data_/graph_C0TvPE51.pt
# Processed and saved: _data_/graph_C3nS7zra.pt
# Processed and saved: _data_/graph_c3vcpYaW.pt
# Processed and saved: _data_/graph_c5uT5wnw.pt
# Processed and saved: _data_/graph_c5V1H5oO.pt
# Processed and saved: _data_/graph_c7skmmZo.pt
# Processed and saved: _data_/graph_ChgQ1qu8.pt
# Processed and saved: _data_/graph_chiOgLxN.pt
# Processed and saved: _data_/graph_5pbeW2At.pt
# Processed and saved: _data_/graph_5pJsm7UB.pt
# Processed and saved: _data_/graph_5SQZO5FA.pt
# Processed and saved: _data_/graph_5vdaasoO.pt
# Processed and saved: _data_/graph_5VEpVxat.pt
# Processed and saved: _data_/graph_5Vt2sSbG.pt
# Processed and saved: _data_/graph_5XfGaqbB.pt
# Processed and saved: _data_/graph_5YNEWaI4.pt
# Processed and saved: _data_/graph_5yv8ZBEj.pt
# Processed and saved: _data_/graph_6d1AKOov.pt
# Processed and saved: _data_/graph_6DzOS7qX.pt
# Processed and saved: _data_/graph_6IiPUinE.pt
# Processed and saved: _data_/graph_6iPumxha.pt
# Processed and saved: _data_/graph_6iVXR80p.pt
# Processed and saved: _data_/graph_6jNbSdtt.pt
# Processed and saved: _data_/graph_6jthMaM5.pt
# Processed and saved: _data_/graph_6k41HFdB.pt
# Processed and saved: _data_/graph_6lff86vW.pt
# Processed and saved: _data_/graph_Ob6qINRA.pt
# Processed and saved: _data_/graph_obCJgpi8.pt
# Processed and saved: _data_/graph_OCMpgkpj.pt
# Processed and saved: _data_/graph_OEtVMmKJ.pt
# Processed and saved: _data_/graph_of81W7m5.pt
# Processed and saved: _data_/graph_ogJrMCjk.pt
# Processed and saved: _data_/graph_oH8UGwXN.pt
# Processed and saved: _data_/graph_oH9Dmn9I.pt
# Processed and saved: _data_/graph_oitlnIgR.pt
# Processed and saved: _data_/graph_OizBh74K.pt
# Processed and saved: _data_/graph_OKCQLcoC.pt
# Processed and saved: _data_/graph_OKWLmok3.pt
# Processed and saved: _data_/graph_olAJbbmO.pt
# Processed and saved: _data_/graph_OlEGX6EZ.pt
# Processed and saved: _data_/graph_Omgy9lvH.pt
# Processed and saved: _data_/graph_ONVny3re.pt
# Processed and saved: _data_/graph_Oo0oVVJ2.pt
# Processed and saved: _data_/graph_opA9jYI3.pt
# Processed and saved: _data_/graph_OQcPv5sz.pt
# Processed and saved: _data_/graph_OQFCUSSo.pt
# Processed and saved: _data_/graph_oQhlj0tv.pt
# Processed and saved: _data_/graph_OrVz1D1V.pt
# Processed and saved: _data_/graph_orxk0I1U.pt
# Processed and saved: _data_/graph_oT6w7pYV.pt
# Processed and saved: _data_/graph_oV8BAvIR.pt
# Processed and saved: _data_/graph_Oxf39Rby.pt
# Processed and saved: _data_/graph_oXOEByNp.pt
# Processed and saved: _data_/graph_OxQ7I9R8.pt
# Processed and saved: _data_/graph_OyzvlqYD.pt
# Processed and saved: _data_/graph_hjB6CWWI.pt
# Processed and saved: _data_/graph_hK1tytkt.pt
# Processed and saved: _data_/graph_hkdx9UZ6.pt
# Processed and saved: _data_/graph_HlfG9bxm.pt
# Processed and saved: _data_/graph_hP6uyljY.pt
# Processed and saved: _data_/graph_hPWBXvBV.pt
# Processed and saved: _data_/graph_HTGStYJe.pt
# Processed and saved: _data_/graph_HtYEwv1A.pt
# Processed and saved: _data_/graph_HUcL6z3g.pt
# Processed and saved: _data_/graph_HuxDPHNZ.pt
# Processed and saved: _data_/graph_HWg9QLZn.pt
# Processed and saved: _data_/graph_hXi9KK9c.pt
# Processed and saved: _data_/graph_hy2KyQOp.pt
# Processed and saved: _data_/graph_hz4vlYhc.pt
# Processed and saved: _data_/graph_hZ6VD67i.pt
# Processed and saved: _data_/graph_i3Ysdvvf.pt
# Processed and saved: _data_/graph_i40cxvUb.pt
# Processed and saved: _data_/graph_x1VsZiZ2.pt
# Processed and saved: _data_/graph_x3MMakPa.pt
# Processed and saved: _data_/graph_x9PpTLak.pt
# Processed and saved: _data_/graph_XacnApgN.pt
# Processed and saved: _data_/graph_XAhcuWzP.pt
# Processed and saved: _data_/graph_XapUx8qp.pt
# Processed and saved: _data_/graph_Xas4YvDz.pt
# Processed and saved: _data_/graph_xay1JnGA.pt
# Processed and saved: _data_/graph_xcC8660D.pt
# Processed and saved: _data_/graph_XcCYuVJo.pt
# Processed and saved: _data_/graph_xEq4sHtY.pt
# Processed and saved: _data_/graph_xGg24p4g.pt
# Processed and saved: _data_/graph_xGn1uyNY.pt
# Processed and saved: _data_/graph_xGNwppEY.pt
# Processed and saved: _data_/graph_xiaIIgF9.pt
# Processed and saved: _data_/graph_XIc5IR9t.pt
# Processed and saved: _data_/graph_xKHxQQSb.pt
# Processed and saved: _data_/graph_xmKI12Eg.pt
# Processed and saved: _data_/graph_Xmusz6gH.pt
# Processed and saved: _data_/graph_xOfGPbFf.pt
# Processed and saved: _data_/graph_xoW6cvrA.pt
# Processed and saved: _data_/graph_RSIcPYhd.pt
# Processed and saved: _data_/graph_rtIeVWUZ.pt
# Processed and saved: _data_/graph_RwjbXZ6l.pt
# Processed and saved: _data_/graph_RwzR2QkS.pt
# Processed and saved: _data_/graph_s4TwWdUt.pt
# Processed and saved: _data_/graph_s65mCkIF.pt
# Processed and saved: _data_/graph_saEBHtOQ.pt
# Processed and saved: _data_/graph_SaJo5YrE.pt
# Processed and saved: _data_/graph_SB4xuaU4.pt
# Processed and saved: _data_/graph_ScD1paw0.pt
# Processed and saved: _data_/graph_scTkgJeI.pt
# Processed and saved: _data_/graph_SeaJ1wsU.pt
# Processed and saved: _data_/graph_SeMI6HkP.pt
# Processed and saved: _data_/graph_SeSqh8Ko.pt
# Processed and saved: _data_/graph_Dxgvcb5G.pt
# Processed and saved: _data_/graph_dxMrSwHb.pt
# Processed and saved: _data_/graph_e6K2YJj1.pt
# Processed and saved: _data_/graph_E6vbSnjV.pt
# Processed and saved: _data_/graph_e8E6uJNJ.pt
# Processed and saved: _data_/graph_E8mKNsQC.pt
# Processed and saved: _data_/graph_EAHHcrVU.pt
# Processed and saved: _data_/graph_eB504jYB.pt
# Processed and saved: _data_/graph_EBbESWu6.pt
# Processed and saved: _data_/graph_eceEjVJZ.pt
# Processed and saved: _data_/graph_EcyxtHWj.pt
# Processed and saved: _data_/graph_edGrVImu.pt
# Processed and saved: _data_/graph_EE5670Qj.pt
# Processed and saved: _data_/graph_EFWxmqhi.pt
# Processed and saved: _data_/graph_efz2WzuU.pt
# Processed and saved: _data_/graph_iZsIWfPL.pt
# Processed and saved: _data_/graph_J0M1gIyM.pt
# Processed and saved: _data_/graph_J0NNGEGY.pt
# Processed and saved: _data_/graph_j2HaHpTP.pt
# Processed and saved: _data_/graph_J33zsIHA.pt
# Processed and saved: _data_/graph_J3YoH1mS.pt
# Processed and saved: _data_/graph_J59EgYpf.pt
# Processed and saved: _data_/graph_j5vkUssX.pt
# Processed and saved: _data_/graph_J7nXoGZl.pt
# Processed and saved: _data_/graph_Jb09j3a8.pt
# Processed and saved: _data_/graph_jbLQSkH9.pt
# Processed and saved: _data_/graph_jddvCWOn.pt
# Processed and saved: _data_/graph_JdrGDe1T.pt
# Processed and saved: _data_/graph_JENnQDav.pt
# Processed and saved: _data_/graph_JGtHxEDt.pt
# Processed and saved: _data_/graph_jHIBiWi4.pt
# Processed and saved: _data_/graph_jiajj6Z5.pt
# Processed and saved: _data_/graph_jJO0NfB9.pt
# Processed and saved: _data_/graph_JkQqfJEa.pt
# Processed and saved: _data_/graph_JmC6VSt4.pt
# Processed and saved: _data_/graph_jnkKONqb.pt
# Processed and saved: _data_/graph_jQ6fmCa4.pt
# Processed and saved: _data_/graph_jSlQknvE.pt
# Processed and saved: _data_/graph_88FIgyCz.pt
# Processed and saved: _data_/graph_8G7Z3MiE.pt
# Processed and saved: _data_/graph_8HjbtLzW.pt
# Processed and saved: _data_/graph_8HPh2GIq.pt
# Processed and saved: _data_/graph_8KitzGJP.pt
# Processed and saved: _data_/graph_8MVEztxK.pt
# Processed and saved: _data_/graph_8oQOyYN4.pt
# Processed and saved: _data_/graph_8p7GlmLu.pt
# Processed and saved: _data_/graph_8qguWWF6.pt
# Processed and saved: _data_/graph_8s6DP1jU.pt
# Processed and saved: _data_/graph_8UKtxtvz.pt
# Processed and saved: _data_/graph_8v23zDlo.pt
# Processed and saved: _data_/graph_8YFrbzGc.pt
# Processed and saved: _data_/graph_8YKSjnrN.pt
# Processed and saved: _data_/graph_8ZIDUoJC.pt
# Processed and saved: _data_/graph_8zJSlJT5.pt
# Processed and saved: _data_/graph_90F6Q4bF.pt
# Processed and saved: _data_/graph_99JrdP5z.pt
# Processed and saved: _data_/graph_99kuZ9dd.pt
# Processed and saved: _data_/graph_GJboacL4.pt
# Processed and saved: _data_/graph_GKpHCxOz.pt
# Processed and saved: _data_/graph_gkRZwPJk.pt
# Processed and saved: _data_/graph_gLzAp4k6.pt
# Processed and saved: _data_/graph_gmhAcMmp.pt
# Processed and saved: _data_/graph_GnkAuzKJ.pt
# Processed and saved: _data_/graph_gNLbsRiz.pt
# Processed and saved: _data_/graph_gRO0Ox0t.pt
# Processed and saved: _data_/graph_GsGyQDQJ.pt
# Processed and saved: _data_/graph_GtE0Ch8c.pt
# Processed and saved: _data_/graph_GTlr0gee.pt
# Processed and saved: _data_/graph_GUjNruaH.pt
# Processed and saved: _data_/graph_gutsyUA1.pt
# Processed and saved: _data_/graph_GWfJLpsS.pt
# Processed and saved: _data_/graph_GXkL4Bx0.pt
# Processed and saved: _data_/graph_Gyb5PRht.pt
# Processed and saved: _data_/graph_gYzAHKxD.pt
# Processed and saved: _data_/graph_H23tdXcs.pt
# Processed and saved: _data_/graph_H2IzdUFv.pt
# Processed and saved: _data_/graph_h3bk5oFL.pt
# Processed and saved: _data_/graph_h4AbhFUL.pt
# Processed and saved: _data_/graph_h4L88nOR.pt
# Processed and saved: _data_/graph_mDHehdMg.pt
# Processed and saved: _data_/graph_MdSml1sd.pt
# Processed and saved: _data_/graph_mEMwlPIf.pt
# Processed and saved: _data_/graph_MfmC2Fia.pt
# Processed and saved: _data_/graph_MH0Nvthk.pt
# Processed and saved: _data_/graph_MHbgHCKR.pt
# Processed and saved: _data_/graph_MJ69vGyT.pt
# Processed and saved: _data_/graph_mk1h9GDz.pt
# Processed and saved: _data_/graph_MkfRB357.pt
# Processed and saved: _data_/graph_MkTb3C02.pt
# Processed and saved: _data_/graph_mlBrhjlU.pt
# Processed and saved: _data_/graph_MLJ7jEYr.pt
# Processed and saved: _data_/graph_Mokfe9cG.pt
# Processed and saved: _data_/graph_MOZdYgNM.pt
# Processed and saved: _data_/graph_MplUj4xV.pt
# Processed and saved: _data_/graph_MRh5cxuo.pt
# Processed and saved: _data_/graph_mRidR8oJ.pt
# Processed and saved: _data_/graph_mUkTMhDR.pt
# Processed and saved: _data_/graph_MUTcmQ4r.pt
# Processed and saved: _data_/graph_muW5XBIZ.pt
# Processed and saved: _data_/graph_ozCntR4O.pt
# Processed and saved: _data_/graph_OzwHMXql.pt
# Processed and saved: _data_/graph_p1J4DBFb.pt
# Processed and saved: _data_/graph_P555o9VI.pt
# Processed and saved: _data_/graph_p6mw01pP.pt
# Processed and saved: _data_/graph_p6OcGlpS.pt
# Processed and saved: _data_/graph_P9N74xBH.pt
# Processed and saved: _data_/graph_pCRN4uhK.pt
# Processed and saved: _data_/graph_PFhb1L8f.pt
# Processed and saved: _data_/graph_PfnmBfVW.pt
# Processed and saved: _data_/graph_PFVSn6rJ.pt
# Processed and saved: _data_/graph_pGb7mUcD.pt
# Processed and saved: _data_/graph_PgyEHcDx.pt
# Processed and saved: _data_/graph_pgzUXgjc.pt
# Processed and saved: _data_/graph_pHHDyGMq.pt
# Processed and saved: _data_/graph_PhXEbsRt.pt
# Processed and saved: _data_/graph_PjzbUVEi.pt
# Processed and saved: _data_/graph_pKO2xGXS.pt
# Processed and saved: _data_/graph_Pkp5XLyB.pt
# Processed and saved: _data_/graph_pLanBTgG.pt
# Processed and saved: _data_/graph_vh1r7Dhn.pt
# Processed and saved: _data_/graph_vIouizrv.pt
# Processed and saved: _data_/graph_VOmZiVXq.pt
# Processed and saved: _data_/graph_vQBvRFJM.pt
# Processed and saved: _data_/graph_VQRvKS1K.pt
# Processed and saved: _data_/graph_vQywTEq0.pt
# Processed and saved: _data_/graph_vsoAuMUF.pt
# Processed and saved: _data_/graph_VtCUaC12.pt
# Processed and saved: _data_/graph_VTIK05Hb.pt
# Processed and saved: _data_/graph_VUuCjYfa.pt
# Processed and saved: _data_/graph_vv0gEsIs.pt
# Processed and saved: _data_/graph_vwc4KjYt.pt
# Processed and saved: _data_/graph_VXiTdI26.pt
# Processed and saved: _data_/graph_vyAHFrxh.pt
# Processed and saved: _data_/graph_vyoPiwEL.pt
# Processed and saved: _data_/graph_VyWuN3Ar.pt
# Processed and saved: _data_/graph_yGDSakzZ.pt
# Processed and saved: _data_/graph_yh7N7CjN.pt
# Processed and saved: _data_/graph_YIBoQlsz.pt
# Processed and saved: _data_/graph_yiKRmhk2.pt
# Processed and saved: _data_/graph_YiL9ArXO.pt
# Processed and saved: _data_/graph_yJTXP0Yj.pt
# Processed and saved: _data_/graph_yk9n4l6U.pt
# Processed and saved: _data_/graph_YmIVFgKB.pt
# Processed and saved: _data_/graph_yoEnJNhi.pt
# Processed and saved: _data_/graph_yofr8dRY.pt
# Processed and saved: _data_/graph_ypHx9CFa.pt
# Processed and saved: _data_/graph_YPiML4mA.pt
# Processed and saved: _data_/graph_Yqa4Kg5T.pt
# Processed and saved: _data_/graph_YrFqTLOF.pt
# Processed and saved: _data_/graph_yrNkzSzP.pt
# Processed and saved: _data_/graph_2R61CWls.pt
# Processed and saved: _data_/graph_2sp7eOYI.pt
# Processed and saved: _data_/graph_2T3iz8Zg.pt
# Processed and saved: _data_/graph_2TBuqvzT.pt
# Processed and saved: _data_/graph_2TUaAnn0.pt
# Processed and saved: _data_/graph_2yNY4lDm.pt
# Processed and saved: _data_/graph_2Zjasn7Q.pt
# Processed and saved: _data_/graph_35wukbvW.pt
# Processed and saved: _data_/graph_3aFB8JPC.pt
# Processed and saved: _data_/graph_3anmoX0A.pt
# Processed and saved: _data_/graph_3bS6tyXw.pt
# Processed and saved: _data_/graph_3DgeixHZ.pt
# Processed and saved: _data_/graph_3DIqLl2D.pt
# Processed and saved: _data_/graph_3dYk74xf.pt
# Processed and saved: _data_/graph_3FiBWLTv.pt
# Processed and saved: _data_/graph_3IMbhboa.pt
# Processed and saved: _data_/graph_3M21ukdm.pt
# Processed and saved: _data_/graph_3MlaeG1q.pt
# Processed and saved: _data_/graph_3OLuOwDc.pt
# Processed and saved: _data_/graph_3s9gfdIW.pt
# Processed and saved: _data_/graph_3TD3osJ6.pt
# Processed and saved: _data_/graph_3u5pSw09.pt
# Processed and saved: _data_/graph_3wEyLv2y.pt
# Processed and saved: _data_/graph_3wi3PJfy.pt
# Processed and saved: _data_/graph_B2CM7uBY.pt
# Processed and saved: _data_/graph_B2esstqX.pt
# Processed and saved: _data_/graph_b2ZQRIDF.pt
# Processed and saved: _data_/graph_B6IsjeE0.pt
# Processed and saved: _data_/graph_BA4A2sa1.pt
# Processed and saved: _data_/graph_bARnitKj.pt
# Processed and saved: _data_/graph_bazS0I7M.pt
# Processed and saved: _data_/graph_bB6teKgO.pt
# Processed and saved: _data_/graph_bbHHpZMA.pt
# Processed and saved: _data_/graph_bCXgdMWC.pt
# Processed and saved: _data_/graph_BDFt0Usw.pt
# Processed and saved: _data_/graph_BEGgVFfm.pt
# Processed and saved: _data_/graph_BeunDFUF.pt
# Processed and saved: _data_/graph_BFI8EiqA.pt
# Processed and saved: _data_/graph_BfpiPBJ7.pt
# Processed and saved: _data_/graph_BFYpYBVz.pt
# Processed and saved: _data_/graph_EWXvzPrO.pt
# Processed and saved: _data_/graph_EX0HSDPB.pt
# Processed and saved: _data_/graph_ExNYfTAA.pt
# Processed and saved: _data_/graph_EYqu7La9.pt
# Processed and saved: _data_/graph_EZ5xMA34.pt
# Processed and saved: _data_/graph_F0iteVmn.pt
# Processed and saved: _data_/graph_f11FewEu.pt
# Processed and saved: _data_/graph_F2LVALZS.pt
# Processed and saved: _data_/graph_F3pEf34i.pt
# Processed and saved: _data_/graph_f4FInX52.pt
# Processed and saved: _data_/graph_F4sFl61j.pt
# Processed and saved: _data_/graph_F7DXKSWb.pt
# Processed and saved: _data_/graph_F9Pi9rNN.pt
# Processed and saved: _data_/graph_FA7i10yV.pt
# Processed and saved: _data_/graph_faDdiTaz.pt
# Processed and saved: _data_/graph_fAElTxYp.pt
# Processed and saved: _data_/graph_faO9T96f.pt
# Processed and saved: _data_/graph_FCF4fbWG.pt
# Processed and saved: _data_/graph_FCVg9Bfn.pt
# Processed and saved: _data_/graph_fDKi2a2m.pt
# Processed and saved: _data_/graph_Fdm5bMOb.pt
# Processed and saved: _data_/graph_fDszLfvX.pt
# Processed and saved: _data_/graph_FFX0FGNW.pt
# Processed and saved: _data_/graph_fgWjTmyC.pt
# Processed and saved: _data_/graph_fi4g24iI.pt
# Processed and saved: _data_/graph_fiU3hGr2.pt
# Processed and saved: _data_/graph_FIyVNfQk.pt
# Processed and saved: _data_/graph_FJsfGfIh.pt
# Processed and saved: _data_/graph_fK5TzRP0.pt
# Processed and saved: _data_/graph_CtGDj9kE.pt
# Processed and saved: _data_/graph_cTppLW9W.pt
# Processed and saved: _data_/graph_CVAQ6R9S.pt
# Processed and saved: _data_/graph_CvqRmuaZ.pt
# Processed and saved: _data_/graph_CxmvPK9D.pt
# Processed and saved: _data_/graph_CXZm7coq.pt
# Processed and saved: _data_/graph_cZddm0hO.pt
# Processed and saved: _data_/graph_CZRf5WUZ.pt
# Processed and saved: _data_/graph_D0NsX7XR.pt
# Processed and saved: _data_/graph_d0V5ZGDs.pt
# Processed and saved: _data_/graph_d0ysyA13.pt
# Processed and saved: _data_/graph_D4RHzSkS.pt
# Processed and saved: _data_/graph_d751sw3q.pt
# Processed and saved: _data_/graph_D7t2XuJu.pt
# Processed and saved: _data_/graph_daCaS6zI.pt
# Processed and saved: _data_/graph_DBl7zLQG.pt
# Processed and saved: _data_/graph_DbPKb2rc.pt
# Processed and saved: _data_/graph_dbpxicdq.pt
# Processed and saved: _data_/graph_t57StB1n.pt
# Processed and saved: _data_/graph_TC7BOXzV.pt
# Processed and saved: _data_/graph_TcEF6B8b.pt
# Processed and saved: _data_/graph_TCnStJVW.pt
# Processed and saved: _data_/graph_TD3ys3YI.pt
# Processed and saved: _data_/graph_tDEipNSL.pt
# Processed and saved: _data_/graph_TE8HuClf.pt
# Processed and saved: _data_/graph_tH96kYbh.pt
# Processed and saved: _data_/graph_thi09dol.pt
# Processed and saved: _data_/graph_tJl3uu6R.pt
# Processed and saved: _data_/graph_tjldKb4l.pt
# Processed and saved: _data_/graph_tlGoo7Fx.pt
# Processed and saved: _data_/graph_TLrENRsp.pt
# Processed and saved: _data_/graph_tLYQJhBm.pt
# Processed and saved: _data_/graph_tnsaSOfd.pt
# Processed and saved: _data_/graph_ToPnUtXV.pt
# Processed and saved: _data_/graph_TPgmR5R9.pt
# Processed and saved: _data_/graph_TqiXWkkb.pt
# Processed and saved: _data_/graph_TQJq85Xb.pt
# Processed and saved: _data_/graph_TrBNq4tU.pt
# Processed and saved: _data_/graph_tSAt183n.pt
# Processed and saved: _data_/graph_tSxFhsFH.pt
# Processed and saved: _data_/graph_tt8PWaOG.pt
# Processed and saved: _data_/graph_TtD6pc2L.pt
# Processed and saved: _data_/graph_Ttiur3Zt.pt
# Processed and saved: _data_/graph_tU1UpKdY.pt
# Processed and saved: _data_/graph_TufKVOfX.pt
# Processed and saved: _data_/graph_tumwtPBd.pt
# Processed and saved: _data_/graph_tV92bQs8.pt
# Processed and saved: _data_/graph_r1eZD3WN.pt
# Processed and saved: _data_/graph_r5IaQogp.pt
# Processed and saved: _data_/graph_r8soAjBR.pt
# Processed and saved: _data_/graph_R9mdGKr2.pt
# Processed and saved: _data_/graph_Re9JGHf5.pt
# Processed and saved: _data_/graph_rFfNL91O.pt
# Processed and saved: _data_/graph_rfS49zYH.pt
# Processed and saved: _data_/graph_rFxUSq5V.pt
# Processed and saved: _data_/graph_rg6VBTii.pt
# Processed and saved: _data_/graph_RgYiR0Yr.pt
# Processed and saved: _data_/graph_rGZKfW3u.pt
# Processed and saved: _data_/graph_Rh1iNYOX.pt
# Processed and saved: _data_/graph_rhRz0wPC.pt
# Processed and saved: _data_/graph_rHwlgksv.pt
# Processed and saved: _data_/graph_rJ4Udygq.pt
# Processed and saved: _data_/graph_RjJZwlTl.pt
# Processed and saved: _data_/graph_RM2mum1h.pt
# Processed and saved: _data_/graph_rM8dasqw.pt
# Processed and saved: _data_/graph_rMKsfL9W.pt
# Processed and saved: _data_/graph_RN43asFY.pt
# Processed and saved: _data_/graph_rnSbfcdD.pt
# Processed and saved: _data_/graph_RoIixHTi.pt
# Processed and saved: _data_/graph_Rowr79bu.pt
# Processed and saved: _data_/graph_RpTYPRhs.pt
# Processed and saved: _data_/graph_RqbB023n.pt
# Processed and saved: _data_/graph_rqdPvbqL.pt
# Processed and saved: _data_/graph_JVS804t3.pt
# Processed and saved: _data_/graph_jX6labV1.pt
# Processed and saved: _data_/graph_jXvuT0ce.pt
# Processed and saved: _data_/graph_JyBKZFdK.pt
# Processed and saved: _data_/graph_JzlvXjRB.pt
# Processed and saved: _data_/graph_K0Vtiv8s.pt
# Processed and saved: _data_/graph_k58HxegY.pt
# Processed and saved: _data_/graph_K5GQo6SX.pt
# Processed and saved: _data_/graph_K6Xbz7SR.pt
# Processed and saved: _data_/graph_kA8v0GQT.pt
# Processed and saved: _data_/graph_kCVudAzx.pt
# Processed and saved: _data_/graph_kGBOzwYp.pt
# Processed and saved: _data_/graph_kgRx0iUz.pt
# Processed and saved: _data_/graph_kgtoVlGK.pt
# Processed and saved: _data_/graph_Kiwat32G.pt
# Processed and saved: _data_/graph_KjVXAMmS.pt
# Processed and saved: _data_/graph_KjXqwhYA.pt
# Processed and saved: _data_/graph_KKhwnW9C.pt
# Processed and saved: _data_/graph_KKMRXs8G.pt
# Processed and saved: _data_/graph_kKpjIhGr.pt
# Processed and saved: _data_/graph_kLDaG0Wt.pt
# Processed and saved: _data_/graph_KLjyYlHW.pt
# Processed and saved: _data_/graph_kmyL98rn.pt
# Processed and saved: _data_/graph_KN6rd3rt.pt
# Processed and saved: _data_/graph_kNl1VEOV.pt
# Processed and saved: _data_/graph_kNVlhuv8.pt
# Processed and saved: _data_/graph_knXjhwGY.pt
# Processed and saved: _data_/graph_KnyJ4XPF.pt
# Processed and saved: _data_/graph_3ZF42CmP.pt
# Processed and saved: _data_/graph_3zlgWYcG.pt
# Processed and saved: _data_/graph_42iRpV2C.pt
# Processed and saved: _data_/graph_47tjkgwM.pt
# Processed and saved: _data_/graph_4AMZuJax.pt
# Processed and saved: _data_/graph_4CpAFaxV.pt
# Processed and saved: _data_/graph_4DFarMIq.pt
# Processed and saved: _data_/graph_4dsmFpSl.pt
# Processed and saved: _data_/graph_4jPuFW7p.pt
# Processed and saved: _data_/graph_4OQS3EEV.pt
# Processed and saved: _data_/graph_4QtuTvZK.pt
# Processed and saved: _data_/graph_4R9JOw7x.pt
# Processed and saved: _data_/graph_4zIXRLse.pt
# Processed and saved: _data_/graph_4ZSrUg5T.pt
# Processed and saved: _data_/graph_59PmDa7F.pt
# Processed and saved: _data_/graph_5abRbrW7.pt
# Processed and saved: _data_/graph_5ASrdudn.pt
# Processed and saved: _data_/graph_5dAYNWfo.pt
# Processed and saved: _data_/graph_5EgPJPA6.pt
# Processed and saved: _data_/graph_5f6Q96LF.pt
# Processed and saved: _data_/graph_5Gec1oAe.pt
# Processed and saved: _data_/graph_5ix50Maq.pt
# Processed and saved: _data_/graph_5JCluXCC.pt
# Processed and saved: _data_/graph_5mrMRZFb.pt
# Processed and saved: _data_/graph_5nWGVH5K.pt
# Processed and saved: _data_/graph_PoqMjy3T.pt
# Processed and saved: _data_/graph_POsdgiRj.pt
# Processed and saved: _data_/graph_pPC9XIo7.pt
# Processed and saved: _data_/graph_Pq4DxyTD.pt
# Processed and saved: _data_/graph_PQJsJQGX.pt
# Processed and saved: _data_/graph_pr61FrVU.pt
# Processed and saved: _data_/graph_PrWxn2yN.pt
# Processed and saved: _data_/graph_psHX51iT.pt
# Processed and saved: _data_/graph_psTuj8fI.pt
# Processed and saved: _data_/graph_pUaMd0Px.pt
# Processed and saved: _data_/graph_PuStoKWo.pt
# Processed and saved: _data_/graph_pV5vDSzp.pt
# Processed and saved: _data_/graph_PXQl4il8.pt
# Processed and saved: _data_/graph_pyz2dhK5.pt
# Processed and saved: _data_/graph_Q05HO8hA.pt
# Processed and saved: _data_/graph_Q2PMijq5.pt
# Processed and saved: _data_/graph_q8PPQgrU.pt
# Processed and saved: _data_/graph_QbrF6upL.pt
# Processed and saved: _data_/graph_Qc8nAgWg.pt
# Processed and saved: _data_/graph_qd5myVcu.pt
# Processed and saved: _data_/graph_qdwzMWPy.pt
# Processed and saved: _data_/graph_qeQ7n6JK.pt
# Processed and saved: _data_/graph_qFnzRWAM.pt
# Processed and saved: _data_/graph_qFriCCuV.pt
# Processed and saved: _data_/graph_qHd528T6.pt
# Processed and saved: _data_/graph_nfEXxf4f.pt
# Processed and saved: _data_/graph_nG6hgUFi.pt
# Processed and saved: _data_/graph_nGdepotS.pt
# Processed and saved: _data_/graph_ngwF5aDO.pt
# Processed and saved: _data_/graph_NhEU85W8.pt
# Processed and saved: _data_/graph_Nhv9xGWT.pt
# Processed and saved: _data_/graph_nJ9BdMjb.pt
# Processed and saved: _data_/graph_njPNKdvJ.pt
# Processed and saved: _data_/graph_nKfqlthh.pt
# Processed and saved: _data_/graph_nkOymQVC.pt
# Processed and saved: _data_/graph_nlRvb9li.pt
# Processed and saved: _data_/graph_nnfq5BAR.pt
# Processed and saved: _data_/graph_nP7uDkgI.pt
# Processed and saved: _data_/graph_npGL5PvW.pt
# Processed and saved: _data_/graph_nPkvPZug.pt
# Processed and saved: _data_/graph_NPLJPi1M.pt
# Processed and saved: _data_/graph_nSVpCdZY.pt
# Processed and saved: _data_/graph_nSWSPTAi.pt
# Processed and saved: _data_/graph_nvYB3hHs.pt
# Processed and saved: _data_/graph_nw7hsTWs.pt
# Processed and saved: _data_/graph_nwXo3ODw.pt
# Processed and saved: _data_/graph_nXiTKDA6.pt
# Processed and saved: _data_/graph_nxoowD45.pt
# Processed and saved: _data_/graph_nXtJ8g20.pt
# Processed and saved: _data_/graph_nyzFDJY5.pt
# Processed and saved: _data_/graph_NzTqC4kh.pt
# Processed and saved: _data_/graph_o2bJ5q5Q.pt
# Processed and saved: _data_/graph_o3TZ6SUO.pt
# Processed and saved: _data_/graph_O4its1zg.pt
# Processed and saved: _data_/graph_o4TBIVGR.pt
# Processed and saved: _data_/graph_zitUk1fO.pt
# Processed and saved: _data_/graph_ZJqsePQM.pt
# Processed and saved: _data_/graph_zKBksm5D.pt
# Processed and saved: _data_/graph_ZKhpbamb.pt
# Processed and saved: _data_/graph_zLbgboiC.pt
# Processed and saved: _data_/graph_zm8oWNnb.pt
# Processed and saved: _data_/graph_ZMoq3bww.pt
# Processed and saved: _data_/graph_zn3XjhsG.pt
# Processed and saved: _data_/graph_ZndcLM5G.pt
# Processed and saved: _data_/graph_ZnoGYFxC.pt
# Processed and saved: _data_/graph_ZnqZxT82.pt
# Processed and saved: _data_/graph_zNW8rZDy.pt
# Processed and saved: _data_/graph_zotpbK6I.pt
# Processed and saved: _data_/graph_ZPS44R7W.pt
# Processed and saved: _data_/graph_ZRiw5sn3.pt
# Processed and saved: _data_/graph_ZShogjTS.pt
# Processed and saved: _data_/graph_zUN8iwUd.pt
# Processed and saved: _data_/graph_ZUuf9G1o.pt
# Processed and saved: _data_/graph_zUVeJFBB.pt
# Processed and saved: _data_/graph_zw8eQcHu.pt
# Processed and saved: _data_/graph_zXTfgDOJ.pt
# Processed and saved: _data_/graph_koGVvcIj.pt
# Processed and saved: _data_/graph_LpLHY8vG.pt
# Processed and saved: _data_/graph_md0dlpY3.pt
# Processed and saved: _data_/graph_MUZB1m2p.pt
# Processed and saved: _data_/graph_Nel805Qs.pt
# Processed and saved: _data_/graph_O5MWkeI5.pt
# Processed and saved: _data_/graph_oz7ChMM2.pt
# Processed and saved: _data_/graph_PMCz2f18.pt
# Processed and saved: _data_/graph_QHoinfXT.pt
# Processed and saved: _data_/graph_r0N9xtaK.pt
# Processed and saved: _data_/graph_RrDblGiZ.pt
# Processed and saved: _data_/graph_sfdVm0AV.pt
# Processed and saved: _data_/graph_T515dk3P.pt
# Processed and saved: _data_/graph_TVkCBKge.pt
# Processed and saved: _data_/graph_UXZKp8oR.pt
# Processed and saved: _data_/graph_vGxKWjcW.pt
# Processed and saved: _data_/graph_W1SlCBjv.pt
# Processed and saved: _data_/graph_wguTRSI1.pt
# Processed and saved: _data_/graph_x1iYNfaH.pt
# Processed and saved: _data_/graph_xpZAPTJi.pt
# Processed and saved: _data_/graph_yeXNjv5P.pt
# Processed and saved: _data_/graph_YshKTikS.pt
# Processed and saved: _data_/graph_Zh0pebxs.pt
# Processed and saved: _data_/graph_lpx4LIlU.pt
# Processed and saved: _data_/graph_Lqux0TE0.pt
# Processed and saved: _data_/graph_LUGitGxj.pt
# Processed and saved: _data_/graph_luiwb2Vi.pt
# Processed and saved: _data_/graph_LVRBypQA.pt
# Processed and saved: _data_/graph_Lw0fVTIt.pt
# Processed and saved: _data_/graph_lWrdRWof.pt
# Processed and saved: _data_/graph_lX5f0t0N.pt
# Processed and saved: _data_/graph_lxWHOpJc.pt
# Processed and saved: _data_/graph_lYGN1UgC.pt
# Processed and saved: _data_/graph_LyqdzjXU.pt
# Processed and saved: _data_/graph_M5rbqiwD.pt
# Processed and saved: _data_/graph_M6exQ92J.pt
# Processed and saved: _data_/graph_M7jjtybb.pt
# Processed and saved: _data_/graph_M7qQ8R6V.pt
# Processed and saved: _data_/graph_M7rVkLRt.pt
# Processed and saved: _data_/graph_M7vpUAAB.pt
# Processed and saved: _data_/graph_M8SLmbIL.pt
# Processed and saved: _data_/graph_m9PCHPA1.pt
# Processed and saved: _data_/graph_MaqMr5f5.pt
# Processed and saved: _data_/graph_WhY51k78.pt
# Processed and saved: _data_/graph_wj3EmGib.pt
# Processed and saved: _data_/graph_Wj5IvYdD.pt
# Processed and saved: _data_/graph_WjXwDpH8.pt
# Processed and saved: _data_/graph_wMCjLOhg.pt
# Processed and saved: _data_/graph_WNeUcN7N.pt
# Processed and saved: _data_/graph_wPfjOwf4.pt
# Processed and saved: _data_/graph_wqAb3kUE.pt
# Processed and saved: _data_/graph_WqJwpz2r.pt
# Processed and saved: _data_/graph_wQnm1WQM.pt
# Processed and saved: _data_/graph_WrZ3lQkZ.pt
# Processed and saved: _data_/graph_WtWia6pU.pt
# Processed and saved: _data_/graph_wuUxbl4k.pt
# Processed and saved: _data_/graph_wvcheCCr.pt
# Processed and saved: _data_/graph_wvuPK7b5.pt
# Processed and saved: _data_/graph_WWVzx8de.pt
# Processed and saved: _data_/graph_Wy4s6ehz.pt
# Processed and saved: _data_/graph_WZNQTRDM.pt
# Processed and saved: _data_/graph_wZXHcQXS.pt
# Processed and saved: _data_/graph_x035Slev.pt
# Processed and saved: _data_/graph_H5OpZgdS.pt
# Processed and saved: _data_/graph_H5PdcHbT.pt
# Processed and saved: _data_/graph_H6UXFGsV.pt
# Processed and saved: _data_/graph_h7gZCFFu.pt
# Processed and saved: _data_/graph_H84R4dGn.pt
# Processed and saved: _data_/graph_hApGRO0p.pt
# Processed and saved: _data_/graph_HarITgqw.pt
# Processed and saved: _data_/graph_hBQxr58C.pt
# Processed and saved: _data_/graph_HCGedyJD.pt
# Processed and saved: _data_/graph_HEi0PkwO.pt
# Processed and saved: _data_/graph_hELYkhJd.pt
# Processed and saved: _data_/graph_heUMMqxE.pt
# Processed and saved: _data_/graph_hfN2z7AB.pt
# Processed and saved: _data_/graph_hfoUZ6f6.pt
# Processed and saved: _data_/graph_HfP9rNN9.pt
# Processed and saved: _data_/graph_Hg0ROOX6.pt
# Processed and saved: _data_/graph_hGTdiw0j.pt
# Processed and saved: _data_/graph_hHIgcfez.pt
# Processed and saved: _data_/graph_xq9tbi4X.pt
# Processed and saved: _data_/graph_xr0SRokb.pt
# Processed and saved: _data_/graph_xR3BfRMu.pt
# Processed and saved: _data_/graph_xTjn0Fna.pt
# Processed and saved: _data_/graph_xTZUf6aU.pt
# Processed and saved: _data_/graph_xWBtTzZi.pt
# Processed and saved: _data_/graph_xwVxvjNP.pt
# Processed and saved: _data_/graph_XXCqkASS.pt
# Processed and saved: _data_/graph_Xyf22gYc.pt
# Processed and saved: _data_/graph_xz18qPNh.pt
# Processed and saved: _data_/graph_XzHqec4I.pt
# Processed and saved: _data_/graph_XzhTjiG5.pt
# Processed and saved: _data_/graph_y0oExV5F.pt
# Processed and saved: _data_/graph_Y1yTRM2R.pt
# Processed and saved: _data_/graph_y5axlh3W.pt
# Processed and saved: _data_/graph_y5jcNmQ9.pt
# Processed and saved: _data_/graph_YclwRJYa.pt
# Processed and saved: _data_/graph_yDAOan64.pt
# Processed and saved: _data_/graph_yDSNyTmV.pt
# Processed and saved: _data_/graph_yEjErx4s.pt
# Processed and saved: _data_/graph_6ScApfKh.pt
# Processed and saved: _data_/graph_6VTXZK6i.pt
# Processed and saved: _data_/graph_6YildNLi.pt
# Processed and saved: _data_/graph_6ZUcQzmQ.pt
# Processed and saved: _data_/graph_7Am1dQSl.pt
# Processed and saved: _data_/graph_7Da42yf2.pt
# Processed and saved: _data_/graph_7f2hysQR.pt
# Processed and saved: _data_/graph_7gIBdQtS.pt
# Processed and saved: _data_/graph_7he21euS.pt
# Processed and saved: _data_/graph_7JNTcTHs.pt
# Processed and saved: _data_/graph_7JxVmGIM.pt
# Processed and saved: _data_/graph_7mseYlki.pt
# Processed and saved: _data_/graph_7nZoiuFP.pt
# Processed and saved: _data_/graph_7o1uVjFo.pt
# Processed and saved: _data_/graph_7p7Cott0.pt
# Processed and saved: _data_/graph_7sgSWbyq.pt
# Processed and saved: _data_/graph_7SmEVgj7.pt
# Processed and saved: _data_/graph_82P1PCt4.pt
# Processed and saved: _data_/graph_83pVzhuk.pt
# Processed and saved: _data_/graph_9cxHsJLl.pt
# Processed and saved: _data_/graph_9cyJvo3K.pt
# Processed and saved: _data_/graph_9Dx6uSHg.pt
# Processed and saved: _data_/graph_9ic5tFBL.pt
# Processed and saved: _data_/graph_9ilCDAQi.pt
# Processed and saved: _data_/graph_9MIv6h0s.pt
# Processed and saved: _data_/graph_9NV36Uvw.pt
# Processed and saved: _data_/graph_9qmuD6bt.pt
# Processed and saved: _data_/graph_9qOTWL8C.pt
# Processed and saved: _data_/graph_9up4D0RS.pt
# Processed and saved: _data_/graph_9W21Hks9.pt
# Processed and saved: _data_/graph_9W8c5q1D.pt
# Processed and saved: _data_/graph_9x2GHj24.pt
# Processed and saved: _data_/graph_9ZcN0z7c.pt
# Processed and saved: _data_/graph_A1RyLIcr.pt
# Processed and saved: _data_/graph_a1vbfpMQ.pt
# Processed and saved: _data_/graph_A5buaKAS.pt
# Processed and saved: _data_/graph_A98HCb4h.pt
# Processed and saved: _data_/graph_a9ZYOU7l.pt
# Processed and saved: _data_/graph_aa3pnUg4.pt
# Processed and saved: _data_/graph_I5s1HtSj.pt
# Processed and saved: _data_/graph_i90tZUO8.pt
# Processed and saved: _data_/graph_iB8AQxYF.pt
# Processed and saved: _data_/graph_Icl07ODi.pt
# Processed and saved: _data_/graph_iGDBTx2E.pt
# Processed and saved: _data_/graph_igDsUM6m.pt
# Processed and saved: _data_/graph_iGMVTFkO.pt
# Processed and saved: _data_/graph_iiYokqhO.pt
# Processed and saved: _data_/graph_IjRNdV6k.pt
# Processed and saved: _data_/graph_ImPsfE5i.pt
# Processed and saved: _data_/graph_ImVD1CIA.pt
# Processed and saved: _data_/graph_ioRwp0on.pt
# Processed and saved: _data_/graph_IPixxUwl.pt
# Processed and saved: _data_/graph_IpWXXC5z.pt
# Processed and saved: _data_/graph_irCT3ryS.pt
# Processed and saved: _data_/graph_ISR5e1Fv.pt
# Processed and saved: _data_/graph_iTrOxqaz.pt
# Processed and saved: _data_/graph_IUC6KiIT.pt
# Processed and saved: _data_/graph_iuTaoQSN.pt
# Processed and saved: _data_/graph_IVFtBGwM.pt
# Processed and saved: _data_/graph_iw9hRsbR.pt
# Processed and saved: _data_/graph_UZl6na6i.pt
# Processed and saved: _data_/graph_uZOgPfcr.pt
# Processed and saved: _data_/graph_v1Ix9FWP.pt
# Processed and saved: _data_/graph_V4BdcL5q.pt
# Processed and saved: _data_/graph_V5I4EwXr.pt
# Processed and saved: _data_/graph_V6FE0MNE.pt
# Processed and saved: _data_/graph_v6tZQov6.pt
# Processed and saved: _data_/graph_Vb7DtAo1.pt
# Processed and saved: _data_/graph_VbKp7cfH.pt
# Processed and saved: _data_/graph_vbP2T7lA.pt
# Processed and saved: _data_/graph_Vc0CeKJZ.pt
# Processed and saved: _data_/graph_Vc5NwDQF.pt
# Processed and saved: _data_/graph_vd2mAjCt.pt
# Processed and saved: _data_/graph_veIyB2Rb.pt
# Processed and saved: _data_/graph_vg3HeZ6n.pt
# Processed and saved: _data_/graph_Vg8ucICx.pt
# Processed and saved: _data_/graph_VgVJzaPZ.pt
# Processed and saved: _data_/graph_1NqxFMJJ.pt
# Processed and saved: _data_/graph_1Olk1uMl.pt
# Processed and saved: _data_/graph_1PQECZpN.pt
# Processed and saved: _data_/graph_1q0KCcSk.pt
# Processed and saved: _data_/graph_1SieV9Xu.pt
# Processed and saved: _data_/graph_1tc9rFqI.pt
# Processed and saved: _data_/graph_1TK36ctl.pt
# Processed and saved: _data_/graph_1ULHpvdM.pt
# Processed and saved: _data_/graph_1y05piuF.pt
# Processed and saved: _data_/graph_1zn1mclb.pt
# Processed and saved: _data_/graph_20LL80zg.pt
# Processed and saved: _data_/graph_21fEgkRt.pt
# Processed and saved: _data_/graph_2AeKWFEe.pt
# Processed and saved: _data_/graph_2aOSK4jm.pt
# Processed and saved: _data_/graph_2aT1HGkj.pt
# Processed and saved: _data_/graph_2bb0kG9m.pt
# Processed and saved: _data_/graph_2dVMYFBo.pt
# Processed and saved: _data_/graph_2gA3O8SR.pt
# Processed and saved: _data_/graph_2IFlERWD.pt
# Processed and saved: _data_/graph_2iwEpyta.pt
# Processed and saved: _data_/graph_2kCd7Jjt.pt
# Processed and saved: _data_/graph_DesSkvJT.pt
# Processed and saved: _data_/graph_DeuD8YBd.pt
# Processed and saved: _data_/graph_djlXbJnU.pt
# Processed and saved: _data_/graph_DJSfs7uD.pt
# Processed and saved: _data_/graph_DJxJBnQd.pt
# Processed and saved: _data_/graph_DlPEZPEx.pt
# Processed and saved: _data_/graph_Dlr1AiXF.pt
# Processed and saved: _data_/graph_DmOwL4Ch.pt
# Processed and saved: _data_/graph_DnKtqUbp.pt
# Processed and saved: _data_/graph_DnO0Nq7C.pt
# Processed and saved: _data_/graph_dqeka0Zd.pt
# Processed and saved: _data_/graph_DR3jWLqg.pt
# Processed and saved: _data_/graph_drqeqpK9.pt
# Processed and saved: _data_/graph_dSkjSOKS.pt
# Processed and saved: _data_/graph_duDrxM5z.pt
# Processed and saved: _data_/graph_DvgiZVYw.pt
# Processed and saved: _data_/graph_DWrSeGoX.pt
# Processed and saved: _data_/graph_dwvtTT67.pt
# Processed and saved: _data_/graph_CiSxq7TV.pt
# Processed and saved: _data_/graph_ciuh1cVa.pt
# Processed and saved: _data_/graph_CJtbt5os.pt
# Processed and saved: _data_/graph_CL347wic.pt
# Processed and saved: _data_/graph_CLanSItf.pt
# Processed and saved: _data_/graph_cLrQrwt5.pt
# Processed and saved: _data_/graph_cmNn3IMC.pt
# Processed and saved: _data_/graph_Cn6wtL6c.pt
# Processed and saved: _data_/graph_Cn9E1X5p.pt
# Processed and saved: _data_/graph_CnfRpZX1.pt
# Processed and saved: _data_/graph_CNq1hUGr.pt
# Processed and saved: _data_/graph_coD2nOG3.pt
# Processed and saved: _data_/graph_cOTle1nG.pt
# Processed and saved: _data_/graph_CpZARCWn.pt
# Processed and saved: _data_/graph_CQfoMCqJ.pt
# Processed and saved: _data_/graph_cSbkdMpW.pt
# Processed and saved: _data_/graph_EkPN3Dka.pt
# Processed and saved: _data_/graph_elTb8IVR.pt
# Processed and saved: _data_/graph_eNhBOMBh.pt
# Processed and saved: _data_/graph_ePGUMEDf.pt
# Processed and saved: _data_/graph_ePLNczkt.pt
# Processed and saved: _data_/graph_ePSCNXO5.pt
# Processed and saved: _data_/graph_EPvhp11w.pt
# Processed and saved: _data_/graph_Eq7RRi1e.pt
# Processed and saved: _data_/graph_EqOGI2Er.pt
# Processed and saved: _data_/graph_EqQb3p3i.pt
# Processed and saved: _data_/graph_EQrQUsmf.pt
# Processed and saved: _data_/graph_eqTlBUEh.pt
# Processed and saved: _data_/graph_ESvfbE0E.pt
# Processed and saved: _data_/graph_EtwWM5Mv.pt
# Processed and saved: _data_/graph_EvkEVbo2.pt
# Processed and saved: _data_/graph_EVLHdhAO.pt
# Processed and saved: _data_/graph_ewhYey8R.pt
# Processed and saved: _data_/graph_EwsJ4nsT.pt
# Processed and saved: _data_/graph_ewt7dqCo.pt
# Processed and saved: _data_/graph_FvIQe0l4.pt
# Processed and saved: _data_/graph_Fvisn4zs.pt
# Processed and saved: _data_/graph_FxFI7TjE.pt
# Processed and saved: _data_/graph_FYLhrPiG.pt
# Processed and saved: _data_/graph_g0bJBf5H.pt
# Processed and saved: _data_/graph_g2aWzLeu.pt
# Processed and saved: _data_/graph_GbUhQzmM.pt
# Processed and saved: _data_/graph_gcwVloSu.pt
# Processed and saved: _data_/graph_GCZxEC2x.pt
# Processed and saved: _data_/graph_ge1aRteh.pt
# Processed and saved: _data_/graph_geo5BhUu.pt
# Processed and saved: _data_/graph_gEYZuems.pt
# Processed and saved: _data_/graph_Gfjm5jQi.pt
# Processed and saved: _data_/graph_GgBSDgFo.pt
# Processed and saved: _data_/graph_GgS7G3XU.pt
# Processed and saved: _data_/graph_ggw84xvG.pt
# Processed and saved: _data_/graph_mwCObbC5.pt
# Processed and saved: _data_/graph_MWjYcOvF.pt
# Processed and saved: _data_/graph_myT1R64C.pt
# Processed and saved: _data_/graph_mZF5bzUR.pt
# Processed and saved: _data_/graph_Mzn7r8tt.pt
# Processed and saved: _data_/graph_mznE1mWu.pt
# Processed and saved: _data_/graph_mzzX76rC.pt
# Processed and saved: _data_/graph_N10h7MaX.pt
# Processed and saved: _data_/graph_N5CFO7P8.pt
# Processed and saved: _data_/graph_N98eFkox.pt
# Processed and saved: _data_/graph_nauxHsyz.pt
# Processed and saved: _data_/graph_nBbYcWVS.pt
# Processed and saved: _data_/graph_NBnkI4gK.pt
# Processed and saved: _data_/graph_ncOXDXDJ.pt
# Processed and saved: _data_/graph_nD1PlStC.pt
# Processed and saved: _data_/graph_nd5pUitt.pt
# Processed and saved: _data_/graph_NDG0ggGg.pt
# Processed and saved: _data_/graph_NdKFdzm5.pt
# Processed and saved: _data_/graph_BhHZESEi.pt
# Processed and saved: _data_/graph_biaESPM7.pt
# Processed and saved: _data_/graph_bKl5ZXHA.pt
# Processed and saved: _data_/graph_BmnO4jO9.pt
# Processed and saved: _data_/graph_bMoFtkHp.pt
# Processed and saved: _data_/graph_BN22ouaK.pt
# Processed and saved: _data_/graph_Bo12cEU1.pt
# Processed and saved: _data_/graph_boLgN59Q.pt
# Processed and saved: _data_/graph_BS0ixK8h.pt
# Processed and saved: _data_/graph_bS4RfXoP.pt
# Processed and saved: _data_/graph_BszyrAEl.pt
# Processed and saved: _data_/graph_BU8coq7R.pt
# Processed and saved: _data_/graph_bVbJkeQf.pt
# Processed and saved: _data_/graph_bvc0aIEN.pt
# Processed and saved: _data_/graph_sfmWFJP4.pt
# Processed and saved: _data_/graph_sGWgklo6.pt
# Processed and saved: _data_/graph_SISCa7pf.pt
# Processed and saved: _data_/graph_SjHJkwRk.pt
# Processed and saved: _data_/graph_sJxpOJs3.pt
# Processed and saved: _data_/graph_SMxMiVzi.pt
# Processed and saved: _data_/graph_SOnpFiyC.pt
# Processed and saved: _data_/graph_sPuqDksi.pt
# Processed and saved: _data_/graph_SQtl44d5.pt
# Processed and saved: _data_/graph_sro28bHL.pt
# Processed and saved: _data_/graph_sUwYsf2H.pt
# Processed and saved: _data_/graph_sVqfbSxJ.pt
# Processed and saved: _data_/graph_sx141CXe.pt
# Processed and saved: _data_/graph_sxATJlgt.pt
# Processed and saved: _data_/graph_SZmmpH6g.pt
# Processed and saved: _data_/graph_T02W9zqs.pt
# Processed and saved: _data_/graph_t0Np1yYg.pt
# Processed and saved: _data_/graph_YubzMZHV.pt
# Processed and saved: _data_/graph_yxScgDPE.pt
# Processed and saved: _data_/graph_Yzt8mUxl.pt
# Processed and saved: _data_/graph_Z3591AJD.pt
# Processed and saved: _data_/graph_z37fo5Wv.pt
# Processed and saved: _data_/graph_Z5k2jCLb.pt
# Processed and saved: _data_/graph_Z5kfg2sU.pt
# Processed and saved: _data_/graph_Z7zuBP6h.pt
# Processed and saved: _data_/graph_z8HHUG1G.pt
# Processed and saved: _data_/graph_zArBWwh1.pt
# Processed and saved: _data_/graph_ZBCUYFsf.pt
# Processed and saved: _data_/graph_ZC7bM1vk.pt
# Processed and saved: _data_/graph_zC8BN5Wy.pt
# Processed and saved: _data_/graph_zFVdt0PS.pt
# Processed and saved: _data_/graph_zFvPwxzb.pt
# Processed and saved: _data_/graph_zGd6tuBr.pt
# Processed and saved: _data_/graph_w7RYYvHQ.pt
# Processed and saved: _data_/graph_w81eMbjv.pt
# Processed and saved: _data_/graph_w8hjXpYs.pt
# Processed and saved: _data_/graph_w8LmTyYY.pt
# Processed and saved: _data_/graph_w8v7aetf.pt
# Processed and saved: _data_/graph_W9eCEaby.pt
# Processed and saved: _data_/graph_w9MrCAPm.pt
# Processed and saved: _data_/graph_WACcQi51.pt
# Processed and saved: _data_/graph_WAuMFeVC.pt
# Processed and saved: _data_/graph_Wcfi3kIc.pt
# Processed and saved: _data_/graph_wewAPUZD.pt
# Processed and saved: _data_/graph_wFpKe2mE.pt
# Processed and saved: _data_/graph_Wg647t9T.pt
# Processed and saved: _data_/graph_wgl6WazW.pt
# Processed and saved: _data_/graph_wGTiynl1.pt
# [+] Done, 1033 graphs have been preprocessd !
